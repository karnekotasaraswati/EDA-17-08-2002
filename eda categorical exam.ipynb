# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
titanic_df=pd.read_csv(r"C:\Users\SONALI\Downloads\Titanic Dataset - Titanic Dataset.csv")
titanic_df
# Out:
#          sex   age  sibsp  parch     fare embarked  class    who  alone  \
# 0        NaN   NaN    NaN    NaN      NaN      NaN    NaN    NaN    NaN
# 1       male  22.0    1.0    0.0   7.2500        S  Third    man  False
# 2        NaN   NaN    NaN    NaN      NaN      NaN    NaN    NaN    NaN
# 3     female  38.0    1.0    0.0  71.2833        C  First  woman  False
# 4        NaN   NaN    NaN    NaN      NaN      NaN    NaN    NaN    NaN
# ...      ...   ...    ...    ...      ...      ...    ...    ...    ...
# 1777  female   NaN    1.0    2.0  23.4500        S  Third  woman  False
# 1778     NaN   NaN    NaN    NaN      NaN      NaN    NaN    NaN    NaN
# 1779    male  26.0    0.0    0.0  30.0000        C  First    man   True
# 1780     NaN   NaN    NaN    NaN      NaN      NaN    NaN    NaN    NaN
# 1781    male  32.0    0.0    0.0   7.7500        Q  Third    man   True
#
#       survived
# 0          NaN
# 1          0.0
# 2          NaN
# 3          1.0
# 4          NaN
# ...

# %%
titanic_df.head(2)
# Out:
#     sex   age  sibsp  parch  fare embarked  class  who  alone  survived
# 0   NaN   NaN    NaN    NaN   NaN      NaN    NaN  NaN    NaN       NaN
# 1  male  22.0    1.0    0.0  7.25        S  Third  man  False       0.0

# %%
titanic_df.select_dtypes(include='object').columns
# Out:
# Index(['sex', 'embarked', 'class', 'who', 'alone'], dtype='object')

# %%
titanic_df.select_dtypes(exclude='object').columns
# Out:
# Index(['age', 'sibsp', 'parch', 'fare', 'survived'], dtype='object')

# %%
titanic_df.take([100,200,300],axis=0)
# Out:
#      sex  age  sibsp  parch  fare embarked class  who alone  survived
# 100  NaN  NaN    NaN    NaN   NaN      NaN   NaN  NaN   NaN       NaN
# 200  NaN  NaN    NaN    NaN   NaN      NaN   NaN  NaN   NaN       NaN
# 300  NaN  NaN    NaN    NaN   NaN      NaN   NaN  NaN   NaN       NaN

# %%
titanic_df.iloc[[200,300]]
# Out:
#      sex  age  sibsp  parch  fare embarked class  who alone  survived
# 200  NaN  NaN    NaN    NaN   NaN      NaN   NaN  NaN   NaN       NaN
# 300  NaN  NaN    NaN    NaN   NaN      NaN   NaN  NaN   NaN       NaN

# %%
titanic_df.iloc[200:300]
# Out:
#         sex   age  sibsp  parch     fare embarked   class    who  alone  \
# 200     NaN   NaN    NaN    NaN      NaN      NaN     NaN    NaN    NaN
# 201  female  28.0    0.0    0.0   7.8958        S   Third  woman   True
# 202     NaN   NaN    NaN    NaN      NaN      NaN     NaN    NaN    NaN
# 203    male   NaN    0.0    0.0   7.8958        S   Third    man   True
# 204     NaN   NaN    NaN    NaN      NaN      NaN     NaN    NaN    NaN
# ..      ...   ...    ...    ...      ...      ...     ...    ...    ...
# 295  female   9.0    2.0    2.0  34.3750        S   Third  child  False
# 296     NaN   NaN    NaN    NaN      NaN      NaN     NaN    NaN    NaN
# 297    male  36.5    0.0    2.0  26.0000        S  Second    man  False
# 298     NaN   NaN    NaN    NaN      NaN      NaN     NaN    NaN    NaN
# 299    male  42.0    0.0    0.0  13.0000        S  Second    man   True
#
#      survived
# 200       NaN
# 201       0.0
# 202       NaN
# 203       0.0
# 204       NaN
# ...

# %%
titanic_df.iloc[200:300,[3,5,]]
# Out:
#      parch embarked
# 200    NaN      NaN
# 201    0.0        S
# 202    NaN      NaN
# 203    0.0        S
# 204    NaN      NaN
# ..     ...      ...
# 295    2.0        S
# 296    NaN      NaN
# 297    2.0        S
# 298    NaN      NaN
# 299    0.0        S
#
# [100 rows x 2 columns]

# %%
titanic_df.loc[200:300,['sex','age','parch']]
# Out:
#         sex   age  parch
# 200     NaN   NaN    NaN
# 201  female  28.0    0.0
# 202     NaN   NaN    NaN
# 203    male   NaN    0.0
# 204     NaN   NaN    NaN
# ..      ...   ...    ...
# 296     NaN   NaN    NaN
# 297    male  36.5    2.0
# 298     NaN   NaN    NaN
# 299    male  42.0    0.0
# 300     NaN   NaN    NaN
#
# [101 rows x 3 columns]

# %%
import matplotlib.pyplot as plt

# %%
titanic_df.columns
# Out:
# Index(['sex', 'age', 'sibsp', 'parch', 'fare', 'embarked', 'class', 'who',
#        'alone', 'survived'],
#       dtype='object')

# %%
plt.figure(figure=(4,2))
plt.bar('g','female',
        data=titantic_df)
plt.title("bar chart")
plt.xlabel("male")
plt.ylabel("female")
plt.savefig("chart.jpg")
plt.savefig("barchart.png")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[34], line 3
#       1 plt.figure(figure=(4,2))
#       2 plt.bar('g','female',
# ----> 3         data=titantic_df)
#       4 plt.title("bar chart")
#       5 plt.xlabel("male")
#
# NameError: name 'titantic_df' is not defined

# %%
tit=titanic_df['sex'].value_counts()
tit.keys()
# Out:
# Index(['male', 'female'], dtype='object', name='sex')

# %%
titanic_df['sex'].unique()
# Out:
# array([nan, 'male', 'female'], dtype=object)

# %%
sir i know this much only i abscent that day because of exams
